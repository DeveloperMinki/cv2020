# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('test11.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[579,336],[754,376],[762,504],[583,488]])
pts2 = np.float32([[570,336],[754,335],[762,496],[570,488]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(0,0))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
cv2.imshow('img',img)
cv2.imshow('tophat',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # ![dfd](https://user-images.githubusercontent.com/49486323/96080884-15c4e880-0ef3-11eb-822c-3fac3edf4ff9.PNG)
